# %% [markdown]
# # Project 1: Ensemble Coefficient of Performance
# ## Spring 2026
# **Course:** Next-Generation Data Centers & Energy Management
#
# Name: First Name, Last Name
# E-mail: email@berkeley.edu
#
# Academic Integrity & AI Policy
# This project is designed to test your ability to integrate complex thermodynamic systems. The use of Generative AI (e.g., ChatGPT, Claude, Gemini) to derive equations, write the analysis, or generate the model is strictly prohibited. The goal is for you to grapple with the coupling of these variables yourself. All work must be your own original derivation and code.
#
# **Objective:** To model the system-level efficiency of a 10 MW data center by integrating individual component thermodynamics into a cohesive energy balance.
#
# ### Project Overview
# So far we have used thermodynamics to analyze individual components in a data center. In this project, you will evaluate the Ensemble Coefficient of Performance ($\text{COP}_\text{sys}$) of a complete data center facility. Your goal is to determine how the coupling of cooling infrastructure and heat rejection systems responds to varying environmental loads, specifically the ambient wet-bulb temperature ($T_\text{wb}$).
#
# Assumptions:
#
# * Medium-to-large scale enterprise data center.
# * Total IT Load ($\dot{Q}_\text{IT}$): $10 \text{ MW}$ (assumed constant).
# * Raised-floor configuration with Hot-Aisle/Cold-Aisle containment.
# * High-performance chips cooled via heatsinks/fans.
# * Room Level: Computer Room Air Handlers (CRAH/CRAC units).
# * Plant Level: Water-cooled Chiller plant with integrated Water-Side Economizer.
# * Heat Rejection: Induced-draft Cooling Towers.
#
# You are required to derive and plot the Ensemble COP ($\text{COP}_\text{sys}$) as a function of the external wet-bulb temperature ($T_\text{wb}$), ranging from $0^\circ\text{C}$ to $35^\circ\text{C}$.
#
# The ensemble COP is defined as the ratio of the total heat removed from the IT equipment to the total work input required by all cooling subsystems.
#
# Please account for the transition between Full Economizer (free cooling), Partial Economizer, and Mechanical Cooling (Chiller-only) modes based on the $T_{wb}$ and the required chilled water supply temperature. Define realistic temperatures for the cooling tower and the heat exchangers such that heat is actually exchanged. Use your previous component models to estimate the power ($\dot{W}$) for each device. For fans and pumps, assume power scales with the cube of the flow rate where applicable.
#
# While assumptions are given, you may need to select additional assumptions, e.g., the capacity of the cooling equipment, the area of the white room (where the IT equipment resides), etc. If such assumptions are needed, please note them and provide justifications.
#
# ## Deliverables
# Your final submission should be a documented Jupyter Notebook containing:
# 1. Diagram: A complete diagram showing all devices and energy exchange processes from the chip to the atmosphere.
# 2. The set of governing equations used to link the $T_\text{wb}$ to the power consumption of each device.
# 3. A high-quality plot showing $\text{COP}_\text{sys}$ vs. $T_\text{wb}$.
# 4. Identify the $T_\text{wb}$ "breakpoints" where the system efficiency drops significantly due to mode switching.
#
# ## Suggested Constants & Assumptions
# * Chilled Water Setpoint: $15^\circ\text{C}$
# * CRAH/CRAC Return Air: $35^\circ\text{C}$
# * Pump/Fan Isentropic Efficiency: $75\%$ (Baseline)
#
# ------

# %% [markdown]
# Please show your work here...
#
# $$ y = m x + b$$
#
# ...

# %%
#code cell; code solutions go here. 
#this is also way you will generate your plot...

# %% [markdown]
# ~~~~
# THIS IS THE LAST CELL, ANYTHING AFTER THIS WILL NOT BE GRADED. PLEASE DO NOT DELETE.
# ~~~~
